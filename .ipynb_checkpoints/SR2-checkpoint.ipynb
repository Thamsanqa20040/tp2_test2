# %%
import pandas as pd

# %%
sihle =pd.read_csv("C:\\Users\\admin\\Downloads\\Informal_Settlement_Programme_-1898186875815614491.csv")

# %%
print(sihle.size)

print(sihle.dtypes)
print(sihle.columns)
print(sihle.head())
# Out:
# 10188
# OBJECTID           int64
# NAME_OF_SE        object
# ALT_NAME          object
# STREETNAME        object
# WARD_S            object
# PLANNING_U        object
# LATITUDE          object
# LONGITUDE         object
# REGION            object
# WATER_SUPP        object
# SANITATION        object
# REFUSE            object
# ELECTRIC_2        object
# UNIREFCODE        object
# EST_HHC            int64
# NUSP_CAT          object
# Shape__Area      float64
# Shape__Length    float64
# dtype: object
# Index(['OBJECTID', 'NAME_OF_SE', 'ALT_NAME', 'STREETNAME', 'WARD_S',
#        'PLANNING_U', 'LATITUDE', 'LONGITUDE', 'REGION', 'WATER_SUPP',
#        'SANITATION', 'REFUSE', 'ELECTRIC_2', 'UNIREFCODE', 'EST_HHC',
#        'NUSP_CAT', 'Shape__Area', 'Shape__Length'],
#       dtype='object')
#    OBJECTID     NAME_OF_SE       ALT_NAME  \
# 0         1       Amatikwe
# 1         2  Congo Phase 2  Congo Phase 2
# 2         3  Africa Inanda         Africa
# 3         4        Namibia
# ...

# %%
slice_1 = sihle.iloc[10:20]
print(slice_1)
print(sihle.index)

sihle.set_index(['OBJECTID', 'DSD_N'], inplace=True)
print(sihle.head())

print(sihle.loc[('OBJECTID', 'DSD_N')])
sihle.reset_index(inplace=True)
print(sihle.head())
# Out:
#     OBJECTID                 NAME_OF_SE     ALT_NAME  \
# 10        11    Gumtree Road (Kenville)
# 11        12       Mysore Road (Temple)
# 12        13            Richmond Farm A
# 13        14                 Siyasokola
# 14        15                Ntuzuma - G
# 15        16                 Parkington   Thandanani
# 16        17                    Gwala's  Gwalas farm
# 17        18                  Zwelitsha
# 18        19  Kwasumubi / eMahlabathini  Cottonlands
# 19        20                   Sitarami
#
#                               STREETNAME WARD_S  \
# 10                          Gumtree Road     34
# 11                  Mysore Road (Temple)     34
# 12           Dukuza Road / Ingcebo Drive     38
# 13                     Sea Cow Lake Road     34
# 14               Umbeza Way / Mbuso Road     42
# 15  Parkington Grove / Park Station Road     34
# 16      Douglas Place / Saunders` Circle     34
# 17     Off Douglas Circle / 80002 Street  61/58
# ...

# %%
missing_data = sihle.isnull().sum()
print(missing_data[missing_data > 0])
sihle.reset_index(inplace=True)
print(sihle.head())
# Out:
# ALT_NAME    4
# dtype: int64
#    index  OBJECTID     NAME_OF_SE       ALT_NAME  \
# 0      0         1       Amatikwe
# 1      1         2  Congo Phase 2  Congo Phase 2
# 2      2         3  Africa Inanda         Africa
# 3      3         4        Namibia
# 4      4         5     Mshayazafe
#
#                                STREETNAME  WARD_S  \
# 0                              MR93 North  56/108
# 1                        MR93 /MR93 North   55/57
# 2                  Curnick Ndlovu Highway      55
# 3  Curnick Ndlovu Highway / Matshana Road  108/44
# 4                            Sidudla Road      55
#
#                       PLANNING_U           LATITUDE         LONGITUDE  \
# 0                       Amatikwe  -29,6847594568261  30,9331993743659
# 1                   Inanda Congo  -29,6930565996813  30,9524428875002
# 2        Ohlange-Africa / Stop 8   -29,700492743755  30,9486579023242
# 3                 Inanda Namibia   -29,703771886581  30,9335017254606
# ...

# %% [markdown]
# slice_1 - This is likely a subset of a larger DataFrame, which i normalyy use to represent datasets and the Data Type for this one is DataFrame.
#
# sihle.index - Index object stands for the index labels of the DataFrame, so the Data type for this one is Index.
#
# sihle- This one is the DtaFrame representing a dataset.It contains multiple colums with different data type. The data type for this one is called DtaFrame.
#
# misssing data- this one is a series object representing missing data counts for each colum in the DtaFrame. So th data type for this one is series
